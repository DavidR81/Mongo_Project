# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import requests
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
response = requests.get("https://maps.googleapis.com/maps/api/place/textsearch/json?query=starbucks+in+san+francisco+city&fields=geometry/location,name&key=AIzaSyBaVysol2EAEyffBgfGK843z0gAcar_6lg")

# %%
sb = response.json()

# %%
sb
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CpQCDgEAADCEIyGiXuSOh6U9b0BjK-PrOrIuaeS02UoTnN6mLTVbY5rx3JZaPZQ25TAcfGBPJ4CedNVvZC_xHEi5Nq4VglKvjjnG9DiTWiZXvMPsbevGCokd7HZAtN5LOQOTDbvRS-knRQmBlYDaCx7b9re6ST4FDRLQalXQrocaZxEVoDxEBrVGo53N_ccxyifYULue0GSci-vSRhsAFc2b1mCQqa1cb9uk8s7KQKIXBzTBkXvF68j3IrU97Ep6nNWv-njj4YhaYbiCNBfM1__Z6KpKrfnoJM-8bifGmRtM1fd9y5cQ7PduRlTghYRGprca3APwrFsowhUlTTclYTvRBFdLTvMoL0uTzGXNlWA0hp6YKxphEhABHfoHd-nCa1R05dxKnIKTGhQk8D6cmwRmUfQf5d5KB9TRNlvTZA',
#  'results': [{'formatted_address': '685 Beach St, San Francisco, CA 94109, USA',
#    'geometry': {'location': {'lat': 37.806565, 'lng': -122.420425},
#     'viewport': {'northeast': {'lat': 37.80796987989272,
#       'lng': -122.4190850701073},
#      'southwest': {'lat': 37.80527022010728, 'lng': -122.4217847298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'ca6f7503c0281c46ed709880acae0b4d2dc432e5',
#    'name': 'Starbucks',
# ...

# %%
def starbucks(dictrandom):
   names=[]
   lats=[]
   long=[]
   for place in dictrandom["results"]:
       names.append(place["name"])
       lats.append(place["geometry"]["location"]["lat"])
       long.append(place["geometry"]["location"]["lng"])
   dictstarbucks = {"name":names, "latitude":lats, "longitude":long}
   return pd.DataFrame(dictstarbucks)
datastarbucks = starbucks(sb)
datastarbucks.head()
# Out:
#         name   latitude   longitude
# 0  Starbucks  37.806565 -122.420425
# 1  Starbucks  37.778262 -122.415038
# 2  Starbucks  37.784124 -122.407653
# 3  Starbucks  37.797644 -122.430395
# 4  Starbucks  37.797007 -122.398107

# %%
import folium
import pandas as pd
from folium.plugins import HeatMap
import requests
from folium.plugins import MeasureControl

# %%
map_starbucks = folium.Map(location=[37.787092, -122.399972], width=750, height=500, zoom_start=15)
for index, row in datastarbucks.iterrows():
    
    folium.CircleMarker([row['latitude'], row['longitude']],
                       radius=9,
                       popup="latitude {}, longitude {}".format(row['latitude'], row['longitude']),
                       fill_color="#F35C50",
                      ).add_to(map_starbucks)
    folium.Marker(location=[37.787092, -122.399972],
                   radius=100
                  ).add_to(map_starbucks)
map_starbucks.add_child(MeasureControl())
map_starbucks.save('./map_starbucks.html') 
map_starbucks
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Oficina situada a 374m del starbucks

# %%
datastarbucks["City"] = "San Francisco"
datastarbucks.head()

def createGeoJson(office):
   return {
       "type":"Point",
       "coordinates":[office["longitude"],office["latitude"]]
   }
datastarbucks['position'] = datastarbucks.apply(createGeoJson, axis=1)

datastarbucks
# Out:
#                  name   latitude   longitude           City  \
# 0           Starbucks  37.806565 -122.420425  San Francisco
# 1           Starbucks  37.778262 -122.415038  San Francisco
# 2   Starbucks Reserve  37.791511 -122.395103  San Francisco
# 3           Starbucks  37.784124 -122.407653  San Francisco
# 4           Starbucks  37.762913 -122.410423  San Francisco
# 5           Starbucks  37.784166 -122.404159  San Francisco
# 6           Starbucks  37.797644 -122.430395  San Francisco
# 7           Starbucks  37.797718 -122.401083  San Francisco
# 8           Starbucks  37.799293 -122.449466  San Francisco
# 9           Starbucks  37.786146 -122.409094  San Francisco
# 10          Starbucks  37.791311 -122.392268  San Francisco
# 11          Starbucks  37.770242 -122.403458  San Francisco
# 12          Starbucks  37.787404 -122.403220  San Francisco
# 13          Starbucks  37.767102 -122.393893  San Francisco
# 14          Starbucks  37.786261 -122.453194  San Francisco
# ...
