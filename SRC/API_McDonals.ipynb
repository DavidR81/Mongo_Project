# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import requests
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
response = requests.get("https://maps.googleapis.com/maps/api/place/textsearch/json?query=mcdonals+in+san+francisco+city&fields=geometry/location,name&key=AIzaSyBaVysol2EAEyffBgfGK843z0gAcar_6lg")

# %%
mc = response.json()

# %%
mc
# Out:
# {'html_attributions': [],
#  'results': [{'formatted_address': '441 Sutter St, San Francisco, CA 94108, USA',
#    'geometry': {'location': {'lat': 37.7891237, 'lng': -122.4076558},
#     'viewport': {'northeast': {'lat': 37.79058197989272,
#       'lng': -122.4063398701073},
#      'southwest': {'lat': 37.78788232010727, 'lng': -122.4090395298928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '974f24f35b30a5b53daa06f6eb7fe2c379ea2d22',
#    'name': "McDonald's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 873,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105987593835493922624/photos">Ahmad Jetha</a>'],
#      'photo_reference': 'CmRaAAAAtfzOeA00It-d9kdylHq5ukIfLHfGXdzWAa7ga218S7JPihY5PpfAwXQVn2lZKkUv-59R5EVmA_MvaS0BXvTzsSxii0UM3I9rvZ4qFwBWr5ATZKiNWQYCa3zMcHrkg19tEhDz4d-h1REP9SW98LZyteL9GhSxAOZKuBE2draDX6BKVCVRUWT6Kw',
#      'width': 1164}],
# ...

# %%
def mcdonals(dictrandom):
   names=[]
   lats=[]
   long=[]
   for place in dictrandom["results"]:
       names.append(place["name"])
       lats.append(place["geometry"]["location"]["lat"])
       long.append(place["geometry"]["location"]["lng"])
   dictmcdonals = {"name":names, "latitude":lats, "longitude":long}
   return pd.DataFrame(dictmcdonals)
mcdonals = mcdonals(mc)
mcdonals.head()
# Out:
#          name   latitude   longitude
# 0  McDonald's  37.789124 -122.407656
# 1  McDonald's  37.808235 -122.414490
# 2  McDonald's  37.793890 -122.399109
# 3  McDonald's  37.788946 -122.401488
# 4  McDonald's  37.726447 -122.476425

# %%
import folium
import pandas as pd
from folium.plugins import HeatMap
import requests
from folium.plugins import MeasureControl

# %%
map_mcdonals = folium.Map(location=[37.787092, -122.399972], width=750, height=500, zoom_start=15)
for index, row in mcdonals.iterrows():
    
    folium.CircleMarker([row['latitude'], row['longitude']],
                       radius=9,
                       popup="latitude {}, longitude {}".format(row['latitude'], row['longitude']),
                       fill_color="#F35C40",
                      ).add_to(map_mcdonals)
    folium.Marker(location=[37.787092, -122.399972],
                   radius=100
                  ).add_to(map_mcdonals)
map_mcdonals.add_child(MeasureControl())
map_mcdonals.save('./map_mcdonals.html') 
map_mcdonals
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# officina situada a 270m del McDonals
